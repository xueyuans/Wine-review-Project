# %%
from sklearn.externals import joblib
import pandas as pd
from sklearn.metrics import r2_score
from sklearn import linear_model
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import re
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from wordcloud import WordCloud, STOPWORDS

init_df = pd.read_csv('/Users/yiyangzhang/CS@Northeastern University/CS7180_AI/Wine-review-Project-master/wine-reviews_data/winemag-data-130k-v2.csv', na_values="?")
init_df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
print("Length of dataframe before duplicates are removed:", len(init_df))
# Out:
# Length of dataframe before duplicates are removed: 129971

# %%
init_df.describe()
# Out:
#           Unnamed: 0         points          price
# count  129971.000000  129971.000000  120975.000000
# mean    64985.000000      88.447138      35.363389
# std     37519.540256       3.039730      41.022218
# min         0.000000      80.000000       4.000000
# 25%     32492.500000      86.000000      17.000000
# 50%     64985.000000      88.000000      25.000000
# 75%     97477.500000      91.000000      42.000000
# max    129970.000000     100.000000    3300.000000

# %%
init_df.dtypes
# Out:
# Unnamed: 0                 int64
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dtype: object

# %%
init_df.isnull().sum()
# Out:
# Unnamed: 0                   0
# country                     63
# description                  0
# designation              37465
# points                       0
# price                     8996
# province                    63
# region_1                 21247
# region_2                 79460
# taster_name              26244
# taster_twitter_handle    31213
# title                        0
# variety                      1
# winery                       0
# dtype: int64

# %% [markdown]
# Drop feature region_2 due to the large amount of null elements.

# %%
df1 = init_df.drop(["region_2"], axis=1)
df1 = df1.dropna()

# %% [markdown]
# ## 1. Data Analysis and Visualization

# %%
sns.countplot(x='points',data = df1, palette='hls' )
plt.show()

# %%
sns.distplot(df1['price'], hist=True,kde=False);
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
df1.boxplot(['price'], rot=90, figsize=(5,5), grid=False)

# %%
# drop the outlier and fill the null with mean value
df2=df1[df1['price']<200]
df2['price'].fillna(df2['price'].mean())
df2.head()
# Out:
#     Unnamed: 0 country                                        description  \
# 4            4      US  Much like the regular bottling from 2012, this...
# 5            5   Spain  Blackberry and raspberry aromas show a typical...
# 6            6   Italy  Here's a bright, informal red that opens with ...
# 9            9  France  This has great depth of flavor with its fresh ...
# 10          10      US  Soft, supple plum envelopes an oaky structure ...
#
#                            designation  points  price           province  \
# 4   Vintner's Reserve Wild Child Block      87   65.0             Oregon
# 5                         Ars In Vitro      87   15.0     Northern Spain
# 6                              Belsito      87   16.0  Sicily & Sardinia
# 9                          Les Natures      87   27.0             Alsace
# 10                      Mountain Cuvée      87   19.0         California
#
#              region_1        taster_name taster_twitter_handle  \
# 4   Willamette Valley       Paul Gregutt           @paulgwine
# 5             Navarra  Michael Schachner           @wineschach
# 6            Vittoria      Kerin O’Keefe          @kerinokeefe
# 9              Alsace         Roger Voss            @vossroger
# 10        Napa Valley     Virginie Boone               @vboone
#
#                                                 title             variety  \
# 4   Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 5   Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
# 6    Terre di Giurfo 2013 Belsito Frappato (Vittoria)            Frappato
# 9   Jean-Baptiste Adam 2012 Les Natures Pinot Gris...          Pinot Gris
# 10  Kirkland Signature 2011 Mountain Cuvée Caberne...  Cabernet Sauvignon
#
#                 winery
# 4         Sweet Cheeks
# 5               Tandem
# 6      Terre di Giurfo
# 9   Jean-Baptiste Adam
# 10  Kirkland Signature

# %%
plt.figure(1,figsize=[10,8])
sns.distplot(df2['price'], kde=False);
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.figure(1,figsize=[10,8])
sns.regplot(x='price', y='points', data=df2)

# %% [markdown]
# Regression might not be a good approach to using price to predict points or use points to predict price.

# %%
# statistics_price = df['price'].groupby(df['country']).mean()
# mean_value2 = [ statistics_price[i] for i in range(len(statistics_price))]

cnt = init_df.groupby(['country',]).mean()['price'].sort_values(ascending=False).to_frame()

plt.figure(figsize=(16,8))
sns.pointplot(x = cnt['price'] ,y = cnt.index ,color='#073a5a',orient='h',markers='o')
plt.title('Country wise average wine price')
plt.xlabel('Price')
plt.ylabel('Country');

# %%
cnt = init_df.groupby(['country']).mean()['points'].sort_values(ascending=False).to_frame()

plt.figure(figsize=(16,8))
sns.pointplot(x = cnt['points'] ,y = cnt.index ,color='#073a5a',orient='h')
plt.title('Country wise average wine ratting')
plt.xlabel('Points');

# %%
cnt = init_df.groupby(['country','points'])['price'].agg(['count','min','max','mean']).sort_values(by='mean',ascending=False)[:20]
cnt.reset_index(inplace=True)
cnt.style.background_gradient(cmap='PuBu',high=0.5)
# Out:
# <style  type="text/css" >
#     #T_dc3948dc_fdeb_11e8_af62_acde48001122row0_col1 {
#             background-color:  #8bb2d4;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row0_col2 {
#             background-color:  #fff7fb;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row0_col3 {
#             background-color:  #2685bb;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row0_col4 {
#             background-color:  #ebe6f2;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row0_col5 {
#             background-color:  #2685bb;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row1_col1 {
#             background-color:  #2685bb;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row1_col2 {
#             background-color:  #f9f2f8;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row1_col3 {
#             background-color:  #eee8f3;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row1_col4 {
#             background-color:  #acc0dd;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row1_col5 {
#             background-color:  #569dc8;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row2_col1 {
#             background-color:  #589ec8;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row2_col2 {
#             background-color:  #fef6fb;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row2_col3 {
#             background-color:  #d1d2e6;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row2_col4 {
#             background-color:  #e6e2ef;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row2_col5 {
#             background-color:  #8eb3d5;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row3_col1 {
#             background-color:  #2685bb;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row3_col2 {
#             background-color:  #fef6fb;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row3_col3 {
#             background-color:  #a4bcda;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row3_col4 {
#             background-color:  #f1ebf5;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row3_col5 {
#             background-color:  #9ab8d8;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row4_col1 {
#             background-color:  #589ec8;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row4_col2 {
#             background-color:  #fdf5fa;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row4_col3 {
#             background-color:  #ede7f2;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row4_col4 {
#             background-color:  #e9e5f1;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row4_col5 {
#             background-color:  #adc1dd;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row5_col1 {
#             background-color:  #b4c4df;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row5_col2 {
#             background-color:  #faf2f8;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row5_col3 {
#             background-color:  #dcdaeb;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row5_col4 {
#             background-color:  #ebe6f2;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row5_col5 {
#             background-color:  #bdc8e1;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row6_col1 {
#             background-color:  #8bb2d4;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row6_col2 {
#             background-color:  #fff7fb;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row6_col3 {
#             background-color:  #a4bcda;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row6_col4 {
#             background-color:  #fbf3f9;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row6_col5 {
#             background-color:  #c4cbe3;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row7_col1 {
#             background-color:  #8bb2d4;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row7_col2 {
#             background-color:  #f3edf5;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row7_col3 {
#             background-color:  #f8f1f8;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row7_col4 {
#             background-color:  #7bacd1;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row7_col5 {
#             background-color:  #c4cbe3;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row8_col1 {
#             background-color:  #2685bb;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row8_col2 {
#             background-color:  #fdf5fa;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row8_col3 {
#             background-color:  #e3e0ee;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row8_col4 {
#             background-color:  #f6eff7;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row8_col5 {
#             background-color:  #dcdaeb;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row9_col1 {
#             background-color:  #b4c4df;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row9_col2 {
#             background-color:  #c0c9e2;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row9_col3 {
#             background-color:  #fcf4fa;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row9_col4 {
#             background-color:  #6fa7ce;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row9_col5 {
#             background-color:  #dfddec;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row10_col1 {
#             background-color:  #2685bb;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row10_col2 {
#             background-color:  #fff7fb;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row10_col3 {
#             background-color:  #c2cbe2;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row10_col4 {
#             background-color:  #fff7fb;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row10_col5 {
#             background-color:  #e2dfee;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row11_col1 {
#             background-color:  #589ec8;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row11_col2 {
#             background-color:  #fef6fb;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row11_col3 {
#             background-color:  #d8d7e9;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row11_col4 {
#             background-color:  #fbf4f9;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row11_col5 {
#             background-color:  #e2dfee;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row12_col1 {
#             background-color:  #589ec8;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row12_col2 {
#             background-color:  #f8f1f8;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row12_col3 {
#             background-color:  #eae6f1;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row12_col4 {
#             background-color:  #f4edf6;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row12_col5 {
#             background-color:  #e9e5f1;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row13_col1 {
#             background-color:  #fff7fb;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row13_col2 {
#             background-color:  #fdf5fa;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row13_col3 {
#             background-color:  #fff7fb;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row13_col4 {
#             background-color:  #ece7f2;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row13_col5 {
#             background-color:  #e9e5f1;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row14_col1 {
#             background-color:  #8bb2d4;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row14_col2 {
#             background-color:  #fdf5fa;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row14_col3 {
#             background-color:  #f1ebf5;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row14_col4 {
#             background-color:  #f4edf6;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row14_col5 {
#             background-color:  #eae6f1;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122row15_col1 {
#             background-color:  #8bb2d4;
#         }    #T_dc3948dc_fdeb_11e8_af62_acde48001122r

# %% [markdown]
# ## Read country location csv file

# %%
# codeCSV = pd.read_csv("wine-reviews_data/country_location.csv")
# codeCSV[:5]
# Out:
#   Abbr                  name  Latitude  Longitude
# 0   AD               Andorra     42.50       1.50
# 1   AE  United Arab Emirates     24.00      54.00
# 2   AF           Afghanistan     33.00      65.00
# 3   AG   Antigua and Barbuda     17.05     -61.80
# 4   AI              Anguilla     18.25     -63.17

# %% [markdown]
# ## Merge wine review and country location file

# %%
# # init_df = init_df.drop(['Unnamed: 0'], 1)
# # data = data.groupby(['country'], as_index=False).agg({'points': ['count', 'mean'], 'price':['count', 'mean']})
# # init_df = init_df.groupby('country').apply(lambda x : x['country'].count() > 50)
# data = pd.merge(init_df,
#                codeCSV[['name','Abbr','Latitude','Longitude']],
#                left_on="country",
#                right_on="name")
# data[:5]
# Out:
#   country                                        description   designation  \
# 0   Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1   Italy  Here's a bright, informal red that opens with ...       Belsito
# 2   Italy  This is dominated by oak and oak-driven aromas...         Rosso
# 3   Italy  Delicate aromas recall white flower and citrus...     Ficiligno
# 4   Italy  Aromas of prune, blackcurrant, toast and oak c...         Aynat
#
#    points  price           province  region_1 region_2    taster_name  \
# 0      87    NaN  Sicily & Sardinia      Etna      NaN  Kerin O’Keefe
# 1      87   16.0  Sicily & Sardinia  Vittoria      NaN  Kerin O’Keefe
# 2      87    NaN  Sicily & Sardinia      Etna      NaN  Kerin O’Keefe
# 3      87   19.0  Sicily & Sardinia   Sicilia      NaN  Kerin O’Keefe
# 4      87   35.0  Sicily & Sardinia   Sicilia      NaN  Kerin O’Keefe
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1          @kerinokeefe   Terre di Giurfo 2013 Belsito Frappato (Vittoria)
# 2          @kerinokeefe             Masseria Setteporte 2012 Rosso  (Etna)
# 3          @kerinokeefe  Baglio di Pianetto 2007 Ficiligno White (Sicilia)
# 4          @kerinokeefe        Canicattì 2009 Aynat Nero d'Avola (Sicilia)
#
#              variety               winery   name Abbr  Latitude  Longitude
# 0        White Blend              Nicosia  Italy   IT     42.83      12.83
# 1           Frappato      Terre di Giurfo  Italy   IT     42.83      12.83
# 2  Nerello Mascalese  Masseria Setteporte  Italy   IT     42.83      12.83
# 3        White Blend   Baglio di Pianetto  Italy   IT     42.83      12.83
# 4       Nero d'Avola            Canicattì  Italy   IT     42.83      12.83

# %% [markdown]
# ### Using groupby to get some related numbers of each country

# %%
# # data = data.apply()
# df_country = data.groupby(['country'], as_index=False).agg({'points': ['count', 'mean'], 'price':['count', 'mean']})
# df_country = df_country.dropna()
# # df_country = data.groupby(['country']).value_counts().loc[lambda x : x>20].reset_index(name='count')
# # print(counts = df_country.groupby('country').count())
# # df_country = df_country.apply(lambda x: x['country, '] > 20)
# df_country 
# # element_group_sizes = df['A'].groupby(df['A']).transform('size')
# # df[element_group_sizes>1]
# Out:
#                    country points             price
#                             count       mean  count       mean
# 0                Argentina   3800  86.710263   3756  24.510117
# 1                  Armenia      2  87.500000      2  14.500000
# 2                Australia   2329  88.580507   2294  35.437663
# 3                  Austria   3345  90.101345   2799  30.762772
# 4   Bosnia and Herzegovina      2  86.500000      2  12.500000
# 5                   Brazil     52  84.673077     47  23.765957
# 6                 Bulgaria    141  87.936170    141  14.645390
# 7                   Canada    257  89.369650    254  35.712598
# 8                    Chile   4472  86.493515   4416  20.786458
# 9                    China      1  89.000000      1  18.000000
# 10                 Croatia     73  87.219178     71  25.450704
# 11                  Cyprus     11  87.181818     11  16.272727
# 12          Czech Republic     12  87.250000     12  24.250000
# 14                  France  22093  88.845109  17776  41.139120
# 15                 Georgia     86  87.686047     84  19.321429
# 16                 Germany   2165  89.851732   2120  42.257547
# 17                  Greece    466  87.283262    461  22.364425
# 18                 Hungary    146  89.191781    145  40.648276
# 19                   India      9  90.222222      9  13.333333
# 20                  Israel    505  88.471287    489  31.768916
# 21                   Italy  19540  88.562231  16914  39.663770
# 22                 Lebanon     35  87.685714     35  30.685714
# 23              Luxembourg      6  88.666667      6  23.333333
# 24               Macedonia     12  86.833333     12  15.583333
# 25                  Mexico     70  85.257143     70  26.785714
# 26                 Moldova     59  87.203390     59  16.745763
# 27                 Morocco     28  88.571429     28  19.500000
# 28             New Zealand   1419  88.303030   1378  26.931785
# 29                    Peru     16  83.562500     16  18.062500
# 30                Portugal   5691  88.250220   4875  26.218256
# 31                 Romania    120  86.400000    120  15.241667
# 32                  Serbia     12  87.500000     12  24.500000
# 33                Slovakia      1  87.000000      1  16.000000
# 34                Slovenia     87  88.068966     80  24.812500
# 35            South Africa   1401  88.056388   1293  24.668987
# 36                   Spain   6645  87.288337   6573  28.215275
# 37             Switzerland      7  88.571429      7  85.285714
# 38                  Turkey     90  88.088889     90  24.633333
# 39                      US  54504  88.563720  54265  36.573464
# 40                 Ukraine     14  84.071429     14   9.214286
# 41                 Uruguay    109  86.752294    109  26.403670

# %%
# df_loc = pd.merge(df_country,
#                codeCSV[['name','Latitude','Longitude']],
#                left_on="country",
#                right_on="name")
# # df_loc = df_loc[df_loc['size'] > 100]
# df_loc[:5]
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/reshape/merge.py:543: UserWarning: merging between different levels can give an unintended result (2 levels on the left, 1 on the right)
#   warnings.warn(msg, UserWarning)
#               (country, )  (points, count)  (points, mean)  (price, count)  \
# 0               Argentina             3800       86.710263            3756
# 1                 Armenia                2       87.500000               2
# 2               Australia             2329       88.580507            2294
# 3                 Austria             3345       90.101345            2799
# 4  Bosnia and Herzegovina                2       86.500000               2
#
#    (price, mean)                    name  Latitude  Longitude
# 0      24.510117               Argentina    -34.00     -64.00
# 1      14.500000                 Armenia     40.00      45.00
# 2      35.437663               Australia    -27.00     133.00
# 3      30.762772                 Austria     47.33      13.33
# 4      12.500000  Bosnia and Herzegovina     44.00      18.00

# %%
# df_loc.columns.get_values()
# Out:
# array([('country', ''), ('points', 'count'), ('points', 'mean'),
#        ('price', 'count'), ('price', 'mean'), 'name', 'Latitude',
#        'Longitude'], dtype=object)

# %% [markdown]
# ### Start mapping (country_geo & marker_cluster &  country choropleth)

# %%
# import os
# import folium
# import json
# from folium.plugins import MarkerCluster

# # Add country geo
# country_geo = os.path.join('wine-reviews_data', 'world-countries.json')

# # Define map
# m = folium.Map(location=[48, -20], zoom_start=2,tiles='Stamen Terrain')

# # Define marker
# marker_cluster = MarkerCluster().add_to(m)

# # Setup locations
# locations = df_loc[['Latitude', 'Longitude']]
# locationlist = locations.values.tolist()
# len(locationlist)

# # Process marker
# for point in range(0, len(locationlist)):
#     folium.Marker(
#         locationlist[point],
#         popup = '--Country Name: ' + df_country['country', ''][point] + '  '
#             +'--Points Size: ' + str(df_country[('points', 'size')][point])+ '  '
#             +'--Points Mean: ' + str(df_country[('points', 'mean')][point].round(2)),
#         icon = folium.Icon(color='blue', icon='Ok-sign'),
#     ).add_to(marker_cluster)

# # Set color bin
# # bins = list(df_country[('points', 'mean')].quantile([0, 0.2, 0.4, 0.6,0.8, 1]))

# # Process country choropleth
# folium.Choropleth(
#     geo_data=country_geo,
#     name='choropleth',
#     data=df_country,
#     columns=['country',('points', 'mean')],
#     key_on='feature.properties.name',
#     fill_color='YlOrRd',
#     fill_opacity=0.7,
#     line_opacity=0.2,
#     nan_fill_color = 'white',
#     legend_name='Mean of points for each country.',
# #     bins=bins,
# #     reset=True
# ).add_to(m)

# folium.LayerControl().add_to(m)

# # Show map
# m
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'size'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.BaseMultiIndexCodesEngine.get_loc()
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3064             except KeyError:
# -> 3065                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3066
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'size'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-164-434f4fbbda13> in <module>()
#      24         popup = '--Country Name: ' + df_country['country', ''][point] + '  '
#      25             +'--Points Size: ' + str(df_country[('points', 'size')][point])+ '  '
# ---> 26             +'--Points Mean: ' + str(df_country[('points', 'mean')][point].round(2)),
#      27         icon = folium.Icon(color='blue', icon='Ok-sign'),
#      28     ).add_to(marker_cluster)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2681             return self._getitem_frame(key)
#    2682         elif is_mi_columns:
# -> 2683             return self._getitem_multilevel(key)
#    2684         else:
#    2685             return self._getitem_column(key)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_multilevel(self, key)
#    2725
#    2726     def _getitem_multilevel(self, key):
# -> 2727         loc = self.columns.get_loc(key)
#    2728         if isinstance(loc, (slice, Series, np.ndarray, Index)):
#    2729             new_columns = self.columns[loc]
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/multi.py in get_loc(self, key, method)
#    2276
#    2277         if keylen == self.nlevels and self.is_unique:
# -> 2278             return self._engine.get_loc(key)
#    2279
#    2280         # -- partial selection or non-unique index
#
# pandas/_libs/index.pyx in pandas._libs.index.BaseMultiIndexCodesEngine.get_loc()
#
# KeyError: ('points', 'size')

# %% [markdown]
# ### Relationship Between country and point

# %%
dictionary = {}

for country in init_df.country.unique():
    filt = init_df.country == country
    point = init_df[filt].points.mean()
    dictionary[country]=point

plt.figure(figsize=(20,5))

sns.barplot([k for k,v in dictionary.items()],[v for k,v in dictionary.items()])
plt.title("Average Scores of Countries")
plt.xticks(rotation=90)
plt.ylim(80,92)
plt.xlabel("Country")
plt.ylabel("Point")
plt.show()

# %%
fig, ax = plt.subplots(figsize = (20,7))
chart = sns.boxplot(x='country',y='points', data=init_df, ax = ax)
plt.xticks(rotation = 90)
plt.show()

# %%
# only pick the country has more than 50 wine reviews
country=init_df.groupby('country').filter(lambda x: len(x) > 50)
df_countryAndPoint = pd.DataFrame({col:vals['points'] for col,vals in country.groupby('country')})
meds = df_countryAndPoint.median()
meds.sort_values(ascending=False, inplace=True)

fig, ax = plt.subplots(figsize = (20,7))
chart = sns.boxplot(x='country',y='points', data=country, order=meds.index, ax = ax)
plt.xticks(rotation = 90)

plt.show()

# %%
fig,ax = plt.subplots(1,2,figsize=(16,8))
ax1,ax2 = ax.flatten()

cnt = init_df.groupby(['country'])['points'].max().sort_values(ascending=False).to_frame()[:15]
sns.barplot(x = cnt['points'], y = cnt.index, palette= 'hot',ax=ax1)
ax1.set_title('Most rated wine in country')
ax1.set_ylabel('Variety')
ax1.set_xlabel('')
cnt = init_df.groupby(['country'])['points'].min().sort_values(ascending=True).to_frame()[:15]
sns.barplot(x = cnt['points'], y = cnt.index, palette = 'ocean',ax=ax2)
ax2.set_title('Least rated wine by country')
ax2.set_ylabel('')
ax2.set_xlabel('')
plt.subplots_adjust(wspace=0.3);

# %% [markdown]
# Since there are only 41 countries in this data set, and from the graph we generated, we can tell the points distribution has some relationship between country and points. So we might keep this feature to do the prediction.

# %% [markdown]
# ### Relationship between variety and point

# %%
init_df['variety'].count()
# Out:
# 129970

# %%
data = init_df.dropna()
data = data.groupby('variety').filter(lambda x: len(x) > 50)
list = data.variety.value_counts().index.tolist()
fig4, ax4 = plt.subplots(figsize = (20,7))
sns.countplot(x='variety', data=data, order = list, ax=ax4)
plt.xticks(rotation = 90)
plt.show()

# %%
data = data.groupby('variety').filter(lambda x: len(x) > 50)

df4 = pd.DataFrame({col:vals['points'] for col,vals in data.groupby('variety')})
meds3 = df4.median()
meds3.sort_values(ascending=False, inplace=True)

fig3, ax3 = plt.subplots(figsize = (20,7))
chart = sns.boxplot(x='variety',y='points', data=data, order=meds3.index, ax = ax3)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# Keep this feature to do the prediction might not have huge significant difference since there are 130k variety feature and the points distribution is not varied a lot even for the different variety.

# %%
fig,ax = plt.subplots(1,2,figsize=(16,8))
ax1,ax2 = ax.flatten()

cnt = init_df.groupby(['province'])['points'].max().sort_values(ascending=False).to_frame()[:20]
sns.barplot(x = cnt['points'], y = cnt.index, palette= 'RdBu',ax=ax1)
ax1.set_title('Highest quality wine in different province')
ax1.set_ylabel('Variety')
ax1.set_xlabel('')
cnt = init_df.groupby(['province'])['points'].min().sort_values(ascending=True).to_frame()[:20]
sns.barplot(x = cnt['points'], y = cnt.index, palette = 'summer',ax=ax2)
ax2.set_title('Lowest quality wine in different province')
ax2.set_ylabel('')
ax2.set_xlabel('')
plt.subplots_adjust(wspace=0.3);

# %%
dictionary = {}

for province in init_df.province.unique():
    filt = init_df.province == province
    point = init_df[filt].points.mean()
    dictionary[province]=point

plt.figure(figsize=(20,5))

sns.barplot([k for k,v in dictionary.items()],[v for k,v in dictionary.items()])
plt.title("Average Scores of Countries")
plt.xticks(rotation=90)
plt.ylim(80,92)
plt.xlabel("Province")
plt.ylabel("Point")
plt.show()

# %% [markdown]
# From the graph we can tell that there exists some relationship between the points distribution and the province feature. But since there are too much province here so it might be hard to use this feature to do the prediction.

# %% [markdown]
# ### Taster Name

# %%
f,ax = plt.subplots(figsize = (16,8))
sns.countplot(y = init_df['taster_name'], palette = 'cividis', ax = ax)
ax.set_title('Taster Name')
ax.set_xlabel('')
ax.set_ylabel('')
# Out:
# Text(0,0.5,'')

# %%
dictionary = {}

for taster_name in init_df.taster_name.unique():
    filt = init_df.taster_name == taster_name
    point = init_df[filt].points.mean()
    dictionary[taster_name]=point

plt.figure(figsize=(20,5))

sns.barplot([k for k,v in dictionary.items()],[v for k,v in dictionary.items()])
plt.title("Average Scores for different Tasters")
plt.xticks(rotation=90)
plt.ylim(80,92)
plt.xlabel("Taster_Name")
plt.ylabel("Point")
plt.show()

# %% [markdown]
# Since there are limited tasters in the data set, this feature may have some impact on the prediction result.

# %% [markdown]
# ### Description

# %%
df_length = init_df[['description','points']]
df_length.head()
# Out:
#                                          description  points
# 0  Aromas include tropical fruit, broom, brimston...      87
# 1  This is ripe and fruity, a wine that is smooth...      87
# 2  Tart and snappy, the flavors of lime flesh and...      87
# 3  Pineapple rind, lemon pith and orange blossom ...      87
# 4  Much like the regular bottling from 2012, this...      87

# %%
df_length = df_length.assign(description_length = df_length['description'].apply(len))
df_length.head()
# Out:
#                                          description  points  \
# 0  Aromas include tropical fruit, broom, brimston...      87
# 1  This is ripe and fruity, a wine that is smooth...      87
# 2  Tart and snappy, the flavors of lime flesh and...      87
# 3  Pineapple rind, lemon pith and orange blossom ...      87
# 4  Much like the regular bottling from 2012, this...      87
#
#    description_length
# 0                 172
# 1                 227
# 2                 186
# 3                 199
# 4                 249

# %%
fig, ax = plt.subplots(figsize=(30,10))
sns.boxplot(x='points', y='description_length', data=df_length)
plt.xticks(fontsize=20) # X Ticks
plt.yticks(fontsize=20) # Y Ticks
ax.set_title('Description Length per Points', fontweight="bold", size=25) # Title
ax.set_ylabel('Description Length', fontsize = 25) # Y label
ax.set_xlabel('Points', fontsize = 25) # X label
plt.show()

# %% [markdown]
# We can tell that there exists relationship between the length of description and the points

# %%
plt.figure(figsize= (8.0,6.0))
plt.title('Word cloud of Description')
wc = WordCloud(max_words=100,max_font_size=40,background_color='white', stopwords = STOPWORDS,colormap='Set1')
wc.generate(' '.join(init_df['description']))
plt.imshow(wc,interpolation="bilinear")
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)
